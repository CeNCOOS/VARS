# %% [markdown]
# ## VARS DwC conversion
#
# This code is adapted from DwC conversion code I worked on early in 2020. It's intended to convert VARS observations one year at a time. It has been tested on 2001, 2010, 2017, and 1989.
#
# Resources:
# - https://dwc.tdwg.org/terms/
# - https://tools.gbif.org/dwca-validator/extension.do?id=dwc:Occurrence
# - https://www.mbari.org/products/research-software/video-annotation-and-reference-system-vars/query-interface/advanced-user-guide/
# - https://www.gbif.org/data-quality-requirements-occurrences

# %%
## Imports

import pandas as pd
import numpy as np

import re # for extracting logon info from text file

import jaydebeapi # for connecting to VARS db
import VARS # for connecting to VARS db

from datetime import datetime # for handling dates
import pytz # for handling time zones

import urllib.request, urllib.parse, json # for dealing with WoRMS API and output
import WoRMS # functions for querying WoRMS REST API

# %% [markdown]
# ### Obtain data from VARS database

# %%
## Extract logon information from text file

# Get list of each line in file
filename = 'VARS_logon_info.txt'
f = open(filename, 'r')
lines = f.readlines()
f.close()

# Function for extracting information from lines
def get_single_quoted_text(s):
    """ 
    Takes string s and returns any text in s that is between the first set of single quotes, removing whitespace. 
    
    Example:
    s = "What if there's more ' than one' sest of single' quotes?"
    get_single_quoted_text(s) --> 's more'
    
    """
    
    extracted_text = re.search('''(?<=')\s*[^']+?\s*(?=')''', s)
    return(extracted_text.group().strip())

# Assign logon info
dr = get_single_quoted_text(lines[2])
name = get_single_quoted_text(lines[3])
pw = get_single_quoted_text(lines[4])
un = get_single_quoted_text(lines[5])
url = get_single_quoted_text(lines[6])

# %% [markdown]
# An explanation of the regex in get_single_quoted_text() can be found here: <br>
# https://stackoverflow.com/questions/42002931/regex-extract-string-between-single-quotes-trim-whitespace?rq=1
#
# The following query is based on one provided by Brian Schlining that avoids pulling embargoed records. These embargos (especially embargoed concepts and dives) may need to be updated.
#
# Currently, the query pulls records from 1989.

# %%
## Build SQL query

sql = """
        SELECT index_recorded_timestamp,
               observation_uuid,
               concept,
               observation_group,
               observer,
               image_url,
               depth_meters,
               latitude,
               longitude,
               oxygen_ml_per_l,
               psi,
               salinity,
               temperature_celsius,
               video_uri,
               video_sequence_name,
               chief_scientist
        FROM annotations a
        WHERE NOT EXISTS (
           SELECT DISTINCT observation_uuid
           FROM annotations b
           WHERE (
             (  -- Delete last 2 years of annotations
             index_recorded_timestamp > DATEADD([year], - 2, GETDATE()) OR
             index_recorded_timestamp IS NULL OR
             index_recorded_timestamp < CAST('1970-01-02' AS datetime)
             )
           OR ( -- Delete embargoes by dive
             dive_number IN ('Ventana 50', 'Ventana 217', 'Ventana 218', 'Ventana 248')
              )
           OR (
             dive_number IN ('Tiburon 1001', 'Tiburon 1029', 'Tiburon 1030', 'Tiburon 1031', 'Tiburon 1032', 'Tiburon 1033', 'Tiburon 1034')
             )
           OR ( -- Delete embargoes by selectedConcept
             concept IN (
                 'Aegina sp. 1',
                 'Ctenophora',
                 'Cydippida 2',
                 'Cydippida',
                 'Intacta',
                 'Llyria',
                 'Lyrocteis',
                 'Lyroctenidae',
                 'Mertensia',
                 'Mertensiidae sp. A',
                 'Mystery Mollusc',
                 'Mystery Mollusc',
                 'Physonectae sp. 1',
                 'Platyctenida sp. 1',
                 'Platyctenida',
                 'Thalassocalycida sp. 1',
                 'Thalassocalycida',
                 'Thliptodon sp. A',
                 'Tjalfiella tristoma',
                 'Tjalfiella',
                 'Tjalfiellidae',
                 'Tuscarantha braueri',
                 'Tuscarantha luciae',
                 'Tuscarantha',
                 'Tuscaretta globosa',
                 'Tuscaretta',
                 'Tuscaridium cygneum',
                 'Tuscaridium',
                 'Tuscarilla campanella',
                 'Tuscarilla nationalis',
                 'Tuscarilla similis',
                 'Tuscarilla',
                 'Tuscarora',
                 'Tuscaroridae'
                 )
            )
        ) AND a.observation_uuid = b.observation_uuid
    ) AND index_recorded_timestamp >= CAST('1989-01-01' AS datetime) 
      AND index_recorded_timestamp <= CAST('1989-12-31' AS datetime)
    """

# %% [markdown]
# NOTE that the following query will not run unless you're VPNed in to MBARI.

# %%
## Query the database

# Get connection
conn = VARS.get_db_conn(dr, url, un, pw, name)

# Submit query
data = VARS.get_data(conn, sql)

# Close connection
conn.close()

# %%
## Check data is there

col_names = data[1]
data = data[0]

data.columns = col_names

print(data.shape)
data.head()
# Out:
# (44747, 16)
#   index_recorded_timestamp                      observation_uuid  \
# 0      1989-05-17 22:32:03  E7A74B35-0C79-41C5-BB4F-3548FB74DBEB
# 1      1989-04-27 17:54:50  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 2      1989-04-27 17:54:50  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 3      1989-09-12 22:01:59  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
# 4      1989-09-12 22:01:59  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
#
#                concept observation_group observer  \
# 0                 shoe               ROV     jana
# 1  Parmaturus xaniurus               ROV   amberR
# 2  Parmaturus xaniurus               ROV   amberR
# 3              eggcase               ROV  unknown
# 4              eggcase               ROV  unknown
#
#                                            image_url  depth_meters   latitude  \
# 0  http://search.mbari.org/ARCHIVE/framegrabs/Ven...    399.269989  36.107510
# 1  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    415.000000  36.612168
# 2  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    415.000000  36.612168
# 3  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    329.489990  36.699454
# 4  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    329.489990  36.699454
#
#     longitude oxygen_ml_per_l    psi   salinity  temperature_celsius  \
# 0 -121.669977            None  174.0  34.230999                6.719
# 1 -122.029075            None   44.0  34.234001                6.259
# 2 -122.029075            None   44.0  34.234001                6.259
# 3 -121.997758            None  228.0  34.127998                7.936
# 4 -121.997758            None  228.0  34.127998                7.936
#
#                     video_uri video_sequence_name chief_scientist
# 0  urn:tid:mbari.org:V0050-07        Ventana 0050     Chris Grech
# 1  urn:tid:mbari.org:V0043-04        Ventana 0043    Chuck Baxter
# 2  urn:tid:mbari.org:V0043-04        Ventana 0043    Chuck Baxter
# 3  urn:tid:mbari.org:V0076-18        Ventana 0076    Chuck Baxter
# 4  urn:tid:mbari.org:V0076-18        Ventana 0076    Chuck Baxter

# %%
## Save the data if you don't want to have to retrieve it every time

data.to_csv('VARS_1989_data.csv', index=False, na_rep='NaN')

# %% [markdown]
# ### Read in saved data (if not pulled directly from the database)

# %%
## Load csv

path = ''
filename = 'VARS_1989_data.csv'
data = pd.read_csv(path+filename, dtype={'image_url': object})

print(data.shape)
data.head()
# Out:
# (44747, 16)
#   index_recorded_timestamp                      observation_uuid  \
# 0      1989-05-17 22:32:03  E7A74B35-0C79-41C5-BB4F-3548FB74DBEB
# 1      1989-04-27 17:54:50  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 2      1989-04-27 17:54:50  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 3      1989-09-12 22:01:59  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
# 4      1989-09-12 22:01:59  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
#
#                concept observation_group observer  \
# 0                 shoe               ROV     jana
# 1  Parmaturus xaniurus               ROV   amberR
# 2  Parmaturus xaniurus               ROV   amberR
# 3              eggcase               ROV  unknown
# 4              eggcase               ROV  unknown
#
#                                            image_url  depth_meters   latitude  \
# 0  http://search.mbari.org/ARCHIVE/framegrabs/Ven...    399.269989  36.107510
# 1  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    415.000000  36.612168
# 2  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    415.000000  36.612168
# 3  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    329.489990  36.699454
# 4  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    329.489990  36.699454
#
#     longitude  oxygen_ml_per_l    psi   salinity  temperature_celsius  \
# 0 -121.669977              NaN  174.0  34.230999                6.719
# 1 -122.029075              NaN   44.0  34.234001                6.259
# 2 -122.029075              NaN   44.0  34.234001                6.259
# 3 -121.997758              NaN  228.0  34.127998                7.936
# 4 -121.997758              NaN  228.0  34.127998                7.936
#
#                     video_uri video_sequence_name chief_scientist
# 0  urn:tid:mbari.org:V0050-07        Ventana 0050     Chris Grech
# 1  urn:tid:mbari.org:V0043-04        Ventana 0043    Chuck Baxter
# 2  urn:tid:mbari.org:V0043-04        Ventana 0043    Chuck Baxter
# 3  urn:tid:mbari.org:V0076-18        Ventana 0076    Chuck Baxter
# 4  urn:tid:mbari.org:V0076-18        Ventana 0076    Chuck Baxter

# %% [markdown]
# ### Pre-processing

# %%
## Drop duplicate rows that arise from associations, which we don't care about here

data = data.drop_duplicates()
print(data.shape)
data.head()
# Out:
# (36184, 16)
#      index_recorded_timestamp                      observation_uuid  \
# 0         1989-05-17 22:32:03  E7A74B35-0C79-41C5-BB4F-3548FB74DBEB
# 1         1989-04-27 17:54:50  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 3         1989-09-12 22:01:59  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
# 5  1989-03-20 22:03:16.644000  63B6895A-4DB2-4F58-AA03-A4F994814952
# 6  1989-03-20 22:03:16.644000  B1164C4F-E511-4FB9-A0DB-CCA3588AB685
#
#                concept observation_group observer  \
# 0                 shoe               ROV     jana
# 1  Parmaturus xaniurus               ROV   amberR
# 3              eggcase               ROV  unknown
# 5              eggcase               ROV  unknown
# 6              eggcase               ROV   amberR
#
#                                            image_url  depth_meters   latitude  \
# 0  http://search.mbari.org/ARCHIVE/framegrabs/Ven...    399.269989  36.107510
# 1  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    415.000000  36.612168
# 3  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...    329.489990  36.699454
# 5  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...           NaN        NaN
# 6  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...           NaN        NaN
#
#     longitude  oxygen_ml_per_l    psi   salinity  temperature_celsius  \
# 0 -121.669977              NaN  174.0  34.230999                6.719
# 1 -122.029075              NaN   44.0  34.234001                6.259
# 3 -121.997758              NaN  228.0  34.127998                7.936
# 5         NaN              NaN    NaN        NaN                  NaN
# 6         NaN              NaN    NaN        NaN                  NaN
#
#                     video_uri video_sequence_name chief_scientist
# 0  urn:tid:mbari.org:V0050-07        Ventana 0050     Chris Grech
# 1  urn:tid:mbari.org:V0043-04        Ventana 0043    Chuck Baxter
# 3  urn:tid:mbari.org:V0076-18        Ventana 0076    Chuck Baxter
# 5  urn:tid:mbari.org:V0033-04        Ventana 0033    Chuck Baxter
# 6  urn:tid:mbari.org:V0033-04        Ventana 0033    Chuck Baxter

# %% [markdown]
# ### Convert

# %%
## Start with basic event data and change headings

converted = data[['index_recorded_timestamp', 'video_sequence_name', 'observation_group', 'chief_scientist']]
converted = converted.rename(columns={
    'index_recorded_timestamp':'eventDate',
    'video_sequence_name':'eventID',
    'observation_group':'samplingProtocol',
    'chief_scientist':'recordedBy'
})
converted.head()
# Out:
#                     eventDate       eventID samplingProtocol    recordedBy
# 0         1989-05-17 22:32:03  Ventana 0050              ROV   Chris Grech
# 1         1989-04-27 17:54:50  Ventana 0043              ROV  Chuck Baxter
# 3         1989-09-12 22:01:59  Ventana 0076              ROV  Chuck Baxter
# 5  1989-03-20 22:03:16.644000  Ventana 0033              ROV  Chuck Baxter
# 6  1989-03-20 22:03:16.644000  Ventana 0033              ROV  Chuck Baxter

# %% [markdown]
# A small number of records have samplingProtocol = NaN. However, they have one of the ROVs indicated in the eventID, so I feel comfortable forcing all records to ROV.

# %%
## Ensure samplingProtocol is always ROV

converted['samplingProtocol'] = 'ROV'
converted.head()
# Out:
#                     eventDate       eventID samplingProtocol    recordedBy
# 0         1989-05-17 22:32:03  Ventana 0050              ROV   Chris Grech
# 1         1989-04-27 17:54:50  Ventana 0043              ROV  Chuck Baxter
# 3         1989-09-12 22:01:59  Ventana 0076              ROV  Chuck Baxter
# 5  1989-03-20 22:03:16.644000  Ventana 0033              ROV  Chuck Baxter
# 6  1989-03-20 22:03:16.644000  Ventana 0033              ROV  Chuck Baxter

# %%
## Remove whitespace from eventID

converted['eventID'] = [event.replace(' ', '_') for event in converted['eventID']]
converted.head()
# Out:
#                     eventDate       eventID samplingProtocol    recordedBy
# 0         1989-05-17 22:32:03  Ventana_0050              ROV   Chris Grech
# 1         1989-04-27 17:54:50  Ventana_0043              ROV  Chuck Baxter
# 3         1989-09-12 22:01:59  Ventana_0076              ROV  Chuck Baxter
# 5  1989-03-20 22:03:16.644000  Ventana_0033              ROV  Chuck Baxter
# 6  1989-03-20 22:03:16.644000  Ventana_0033              ROV  Chuck Baxter

# %% [markdown]
# **Note** that this code also places an underscore between 'Doc' and 'Ricketts'. It's possible that using 'DocRicketts' could be preferable.

# %%
## Add datasetID

converted['datasetID'] = 'VARS'

# %%
## Add institutionCode

converted['institutionCode'] = 'MBARI'
converted.head()
# Out:
#                     eventDate       eventID samplingProtocol    recordedBy  \
# 0         1989-05-17 22:32:03  Ventana_0050              ROV   Chris Grech
# 1         1989-04-27 17:54:50  Ventana_0043              ROV  Chuck Baxter
# 3         1989-09-12 22:01:59  Ventana_0076              ROV  Chuck Baxter
# 5  1989-03-20 22:03:16.644000  Ventana_0033              ROV  Chuck Baxter
# 6  1989-03-20 22:03:16.644000  Ventana_0033              ROV  Chuck Baxter
#
#   datasetID institutionCode
# 0      VARS           MBARI
# 1      VARS           MBARI
# 3      VARS           MBARI
# 5      VARS           MBARI
# 6      VARS           MBARI

# %%
## Format eventDate

formatted = []

for dt in converted['eventDate']:
    
    # Convert string to datetime
    try:
        dt = datetime.strptime(dt, '%Y-%m-%d %H:%M:%S.%f') # some datetimes have milliseconds
    except ValueError:
        dt = datetime.strptime(dt, '%Y-%m-%d %H:%M:%S')
        
    # Assign UTC timezone
#     utc = pytz.UTC
#     dt = dt.astimezone(utc)
    
    # Put in ISO format string
    dt = dt.isoformat()
    
    # Save in list
    formatted.append(dt + 'Z')

converted['eventDate'] = formatted
converted.head()
# Out:
#                      eventDate       eventID samplingProtocol    recordedBy  \
# 0         1989-05-17T22:32:03Z  Ventana_0050              ROV   Chris Grech
# 1         1989-04-27T17:54:50Z  Ventana_0043              ROV  Chuck Baxter
# 3         1989-09-12T22:01:59Z  Ventana_0076              ROV  Chuck Baxter
# 5  1989-03-20T22:03:16.644000Z  Ventana_0033              ROV  Chuck Baxter
# 6  1989-03-20T22:03:16.644000Z  Ventana_0033              ROV  Chuck Baxter
#
#   datasetID institutionCode
# 0      VARS           MBARI
# 1      VARS           MBARI
# 3      VARS           MBARI
# 5      VARS           MBARI
# 6      VARS           MBARI

# %%
## Add in occurrence-related columns from data, renaming as needed

converted['occurrenceID'] = data['observation_uuid']
converted['scientificName'] = data['concept']
converted['occurrenceRemarks'] = data['concept']
converted['identifiedBy'] = data['observer']
converted['minimumDepthInMeters'] = round(data['depth_meters'], 1) - 2.2 # Sensor is at most 2 m shallower than camera/observed organism (?), and sensor is accurate within 20 cm
converted['maximumDepthInMeters'] = round(data['depth_meters'], 1) + 2.2
converted['verbatimDepth'] = round(data['depth_meters'], 1)
converted['decimalLatitude'] = data['latitude']
converted['decimalLongitude'] = data['longitude']
converted['dissolvedOxygenInMLPerL'] = data['oxygen_ml_per_l']
converted['pressureInPsi'] = data['psi']
converted['salinity'] = data['salinity']
converted['temperatureInCelsius'] = data['temperature_celsius']
converted['image_url'] = data['image_url']
converted['video_uri'] = data['video_uri']
converted.head()
# Out:
#                      eventDate       eventID samplingProtocol    recordedBy  \
# 0         1989-05-17T22:32:03Z  Ventana_0050              ROV   Chris Grech
# 1         1989-04-27T17:54:50Z  Ventana_0043              ROV  Chuck Baxter
# 3         1989-09-12T22:01:59Z  Ventana_0076              ROV  Chuck Baxter
# 5  1989-03-20T22:03:16.644000Z  Ventana_0033              ROV  Chuck Baxter
# 6  1989-03-20T22:03:16.644000Z  Ventana_0033              ROV  Chuck Baxter
#
#   datasetID institutionCode                          occurrenceID  \
# 0      VARS           MBARI  E7A74B35-0C79-41C5-BB4F-3548FB74DBEB
# 1      VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 3      VARS           MBARI  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
# 5      VARS           MBARI  63B6895A-4DB2-4F58-AA03-A4F994814952
# 6      VARS           MBARI  B1164C4F-E511-4FB9-A0DB-CCA3588AB685
#
#         scientificName    occurrenceRemarks identifiedBy  ...  \
# 0                 shoe                 shoe         jana  ...
# 1  Parmaturus xaniurus  Parmaturus xaniurus       amberR  ...
# 3              eggcase              eggcase      unknown  ...
# 5              eggcase              eggcase      unknown  ...
# 6              eggcase              eggcase       amberR  ...
#
#    maximumDepthInMeters  verbatimDepth  decimalLatitude  decimalLongitude  \
# 0                 401.5          399.3        36.107510       -121.669977
# 1                 417.2          415.0        36.612168       -122.029075
# 3                 331.7          329.5        36.699454       -121.997758
# 5                   NaN            NaN              NaN               NaN
# 6                   NaN            NaN              NaN               NaN
#
#    dissolvedOxygenInMLPerL  pressureInPsi   salinity  temperatureInCelsius  \
# 0                      NaN          174.0  34.230999                 6.719
# 1                      NaN           44.0  34.234001                 6.259
# 3                      NaN          228.0  34.127998                 7.936
# 5                      NaN            NaN        NaN                   NaN
# 6                      NaN            NaN        NaN                   NaN
#
#                                            image_url  \
# 0  http://search.mbari.org/ARCHIVE/framegrabs/Ven...
# 1  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 3  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 5  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 6  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
#                     video_uri
# 0  urn:tid:mbari.org:V0050-07
# 1  urn:tid:mbari.org:V0043-04
# 3  urn:tid:mbari.org:V0076-18
# 5  urn:tid:mbari.org:V0033-04
# 6  urn:tid:mbari.org:V0033-04
#
# [5 rows x 21 columns]

# %%
## Add coordinateUncertaintyInMeters 

converted['coordinateUncertaintyInMeters'] = 300
converted.head()
# Out:
#                      eventDate       eventID samplingProtocol    recordedBy  \
# 0         1989-05-17T22:32:03Z  Ventana_0050              ROV   Chris Grech
# 1         1989-04-27T17:54:50Z  Ventana_0043              ROV  Chuck Baxter
# 3         1989-09-12T22:01:59Z  Ventana_0076              ROV  Chuck Baxter
# 5  1989-03-20T22:03:16.644000Z  Ventana_0033              ROV  Chuck Baxter
# 6  1989-03-20T22:03:16.644000Z  Ventana_0033              ROV  Chuck Baxter
#
#   datasetID institutionCode                          occurrenceID  \
# 0      VARS           MBARI  E7A74B35-0C79-41C5-BB4F-3548FB74DBEB
# 1      VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 3      VARS           MBARI  4FF3A4DB-19AE-4C66-8D3F-7096FA5858E2
# 5      VARS           MBARI  63B6895A-4DB2-4F58-AA03-A4F994814952
# 6      VARS           MBARI  B1164C4F-E511-4FB9-A0DB-CCA3588AB685
#
#         scientificName    occurrenceRemarks identifiedBy  ...  verbatimDepth  \
# 0                 shoe                 shoe         jana  ...          399.3
# 1  Parmaturus xaniurus  Parmaturus xaniurus       amberR  ...          415.0
# 3              eggcase              eggcase      unknown  ...          329.5
# 5              eggcase              eggcase      unknown  ...            NaN
# 6              eggcase              eggcase       amberR  ...            NaN
#
#    decimalLatitude  decimalLongitude  dissolvedOxygenInMLPerL  pressureInPsi  \
# 0        36.107510       -121.669977                      NaN          174.0
# 1        36.612168       -122.029075                      NaN           44.0
# 3        36.699454       -121.997758                      NaN          228.0
# 5              NaN               NaN                      NaN            NaN
# 6              NaN               NaN                      NaN            NaN
#
#     salinity  temperatureInCelsius  \
# 0  34.230999                 6.719
# 1  34.234001                 6.259
# 3  34.127998                 7.936
# 5        NaN                   NaN
# 6        NaN                   NaN
#
#                                            image_url  \
# 0  http://search.mbari.org/ARCHIVE/framegrabs/Ven...
# 1  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 3  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 5  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 6  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
#                     video_uri coordinateUncertaintyInMeters
# 0  urn:tid:mbari.org:V0050-07                           300
# 1  urn:tid:mbari.org:V0043-04                           300
# 3  urn:tid:mbari.org:V0076-18                           300
# 5  urn:tid:mbari.org:V0033-04                           300
# 6  urn:tid:mbari.org:V0033-04                           300
#
# [5 rows x 22 columns]

# %%
## Get a list of unique concept names

converted['scientificName'] = [name.lower().strip() for name in converted['scientificName']]
names = converted['scientificName'].unique()

# %%
## Get names of all animals in VARS

animalia = pd.read_json('http://m3.shore.mbari.org/kb/v1/phylogeny/taxa/Animalia')
animalia['name'] = animalia['name'].str.lower()

# %%
## Filter dataframe to include only animal concepts, and reformulate names list

converted = converted[converted['scientificName'].isin(animalia['name']) == True].copy()
names = converted['scientificName'].unique()

# %% [markdown]
# NOTE that we are also interested in other forms of life - algae, etc. So maybe we can ask Brian if that's available?
#
# I ALSO HAVEN'T DONE ANY CHECKING OF WHAT'S FILTERED OUT DURING THIS STEP.

# %%
## Look up names in WoRMS

name_id_dic, name_dic, id_dic, class_dic = WoRMS.run_get_worms_from_scientific_name(names, verbose_flag=True)
# Out:
# Url didn't work for opisthoteuthis cf. californiana checking:  opisthoteuthis
# Url didn't work, check name:  teuthoidea

# %% [markdown]
# Normally I check through names that didn't match manually, but I don't have time right now. Based on work I did in 2020, I have a note that 'teuthoidea' should be 'teuthida'.

# %% [markdown]
# #### Handle organisms that should have matched on WoRMS but didn't

# %%
## Create a dictionary mapping biological names that didn't match on WoRMS to names that should match

VARS_to_WoRMS_dict = {'teuthoidea':'teuthida'}

# %%
## Run these additional terms through WoRMS

revised_concepts = ['teuthida']
revised_name_id_dic, revised_name_dic, revised_id_dic, revised_class_dic = WoRMS.run_get_worms_from_scientific_name(revised_concepts, verbose_flag=True)

# %%
## Add values for revised names to original WoRMS output

name_id_dic.update(revised_name_id_dic)
name_dic.update(revised_name_dic)
id_dic.update(revised_id_dic)

# %%
## Create columns from WoRMS data

# Replace names that don't have a WoRMS match in scientificName with revised names
converted['scientificName'].replace(VARS_to_WoRMS_dict, inplace=True)

# Create scientificNameID column with the same content as scientificName - strip to ensure no whitespace, lowercase
converted['scientificNameID'] = converted['scientificName'].str.strip().str.lower()

# Use dictionary to replace scientific names with name IDs
converted.replace({'scientificNameID':name_id_dic}, inplace=True)

# Repeat to create taxonID
converted['taxonID'] = converted['scientificName'].str.strip().str.lower()
converted.replace({'taxonID':id_dic}, inplace=True)

converted.head()
# Out:
#                eventDate       eventID samplingProtocol     recordedBy  \
# 1   1989-04-27T17:54:50Z  Ventana_0043              ROV   Chuck Baxter
# 12  1989-05-17T17:13:42Z  Ventana_0050              ROV    Chris Grech
# 14  1989-09-12T22:01:07Z  Ventana_0076              ROV   Chuck Baxter
# 19  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
# 22  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
#
#    datasetID institutionCode                          occurrenceID  \
# 1       VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 12      VARS           MBARI  6198DB37-934F-478A-9820-251627551327
# 14      VARS           MBARI  7A96AB28-8188-425B-BB9F-92E9F35E12FF
# 19      VARS           MBARI  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75
# 22      VARS           MBARI  D09D6A8C-8DDA-4431-81AB-971872DE96A6
#
#                scientificName          occurrenceRemarks identifiedBy  ...  \
# 1         parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
# 12                 parmaturus                 Parmaturus       amberR  ...
# 14                galatheidae                Galatheidae      unknown  ...
# 19  rathbunaster californicus  Rathbunaster californicus      unknown  ...
# 22        parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
#
#     decimalLongitude  dissolvedOxygenInMLPerL  pressureInPsi   salinity  \
# 1        -122.029075                      NaN           44.0  34.234001
# 12       -121.669329                      NaN          142.0  34.224998
# 14       -121.997843                      NaN          226.0  34.132000
# 19       -122.018691                      NaN           72.0        NaN
# 22       -122.018691                      NaN           72.0        NaN
#
#     temperatureInCelsius                                          image_url  \
# 1                  6.259  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12                 6.996  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14                 7.930  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19                   NaN  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22                   NaN  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
#                      video_uri  coordinateUncertaintyInMeters  \
# 1   urn:tid:mbari.org:V0043-04                            300
# 12  urn:tid:mbari.org:V0050-02                            300
# 14  urn:tid:mbari.org:V0076-18                            300
# 19  urn:tid:mbari.org:V0049-01                            300
# 22  urn:tid:mbari.org:V0049-01                            300
#
#                              scientificNameID taxonID
# 1   urn:lsid:marinespecies.org:taxname:282166  282166
# 12  urn:lsid:marinespecies.org:taxname:270301  270301
# 14  urn:lsid:marinespecies.org:taxname:106733  106733
# 19  urn:lsid:marinespecies.org:taxname:254844  254844
# 22  urn:lsid:marinespecies.org:taxname:282166  282166
#
# [5 rows x 24 columns]

# %%
## Replace scientificName with matched scientific names from WoRMS

converted['scientificName'] = converted['scientificName'].str.strip().str.lower()
converted['scientificName'].replace(name_dic, inplace=True)
converted.head()
# Out:
#                eventDate       eventID samplingProtocol     recordedBy  \
# 1   1989-04-27T17:54:50Z  Ventana_0043              ROV   Chuck Baxter
# 12  1989-05-17T17:13:42Z  Ventana_0050              ROV    Chris Grech
# 14  1989-09-12T22:01:07Z  Ventana_0076              ROV   Chuck Baxter
# 19  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
# 22  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
#
#    datasetID institutionCode                          occurrenceID  \
# 1       VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 12      VARS           MBARI  6198DB37-934F-478A-9820-251627551327
# 14      VARS           MBARI  7A96AB28-8188-425B-BB9F-92E9F35E12FF
# 19      VARS           MBARI  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75
# 22      VARS           MBARI  D09D6A8C-8DDA-4431-81AB-971872DE96A6
#
#                scientificName          occurrenceRemarks identifiedBy  ...  \
# 1         Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
# 12                 Parmaturus                 Parmaturus       amberR  ...
# 14                Galatheidae                Galatheidae      unknown  ...
# 19  Rathbunaster californicus  Rathbunaster californicus      unknown  ...
# 22        Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
#
#     decimalLongitude  dissolvedOxygenInMLPerL  pressureInPsi   salinity  \
# 1        -122.029075                      NaN           44.0  34.234001
# 12       -121.669329                      NaN          142.0  34.224998
# 14       -121.997843                      NaN          226.0  34.132000
# 19       -122.018691                      NaN           72.0        NaN
# 22       -122.018691                      NaN           72.0        NaN
#
#     temperatureInCelsius                                          image_url  \
# 1                  6.259  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12                 6.996  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14                 7.930  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19                   NaN  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22                   NaN  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
#                      video_uri  coordinateUncertaintyInMeters  \
# 1   urn:tid:mbari.org:V0043-04                            300
# 12  urn:tid:mbari.org:V0050-02                            300
# 14  urn:tid:mbari.org:V0076-18                            300
# 19  urn:tid:mbari.org:V0049-01                            300
# 22  urn:tid:mbari.org:V0049-01                            300
#
#                              scientificNameID taxonID
# 1   urn:lsid:marinespecies.org:taxname:282166  282166
# 12  urn:lsid:marinespecies.org:taxname:270301  270301
# 14  urn:lsid:marinespecies.org:taxname:106733  106733
# 19  urn:lsid:marinespecies.org:taxname:254844  254844
# 22  urn:lsid:marinespecies.org:taxname:282166  282166
#
# [5 rows x 24 columns]

# %%
## Create additional needed columns

converted['nameAccordingTo'] = 'WoRMS'
converted['occurrenceStatus'] = 'present'
converted['basisOfRecord'] = 'MachineObservation'

converted.head()
# Out:
#                eventDate       eventID samplingProtocol     recordedBy  \
# 1   1989-04-27T17:54:50Z  Ventana_0043              ROV   Chuck Baxter
# 12  1989-05-17T17:13:42Z  Ventana_0050              ROV    Chris Grech
# 14  1989-09-12T22:01:07Z  Ventana_0076              ROV   Chuck Baxter
# 19  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
# 22  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
#
#    datasetID institutionCode                          occurrenceID  \
# 1       VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 12      VARS           MBARI  6198DB37-934F-478A-9820-251627551327
# 14      VARS           MBARI  7A96AB28-8188-425B-BB9F-92E9F35E12FF
# 19      VARS           MBARI  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75
# 22      VARS           MBARI  D09D6A8C-8DDA-4431-81AB-971872DE96A6
#
#                scientificName          occurrenceRemarks identifiedBy  ...  \
# 1         Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
# 12                 Parmaturus                 Parmaturus       amberR  ...
# 14                Galatheidae                Galatheidae      unknown  ...
# 19  Rathbunaster californicus  Rathbunaster californicus      unknown  ...
# 22        Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
#
#      salinity  temperatureInCelsius  \
# 1   34.234001                 6.259
# 12  34.224998                 6.996
# 14  34.132000                 7.930
# 19        NaN                   NaN
# 22        NaN                   NaN
#
#                                             image_url  \
# 1   http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
#                      video_uri  coordinateUncertaintyInMeters  \
# 1   urn:tid:mbari.org:V0043-04                            300
# 12  urn:tid:mbari.org:V0050-02                            300
# 14  urn:tid:mbari.org:V0076-18                            300
# 19  urn:tid:mbari.org:V0049-01                            300
# 22  urn:tid:mbari.org:V0049-01                            300
#
#                              scientificNameID  taxonID  nameAccordingTo  \
# 1   urn:lsid:marinespecies.org:taxname:282166   282166            WoRMS
# 12  urn:lsid:marinespecies.org:taxname:270301   270301            WoRMS
# 14  urn:lsid:marinespecies.org:taxname:106733   106733            WoRMS
# 19  urn:lsid:marinespecies.org:taxname:254844   254844            WoRMS
# 22  urn:lsid:marinespecies.org:taxname:282166   282166            WoRMS
#
#     occurrenceStatus       basisOfRecord
# 1            present  MachineObservation
# 12           present  MachineObservation
# 14           present  MachineObservation
# 19           present  MachineObservation
# 22           present  MachineObservation
#
# [5 rows x 27 columns]

# %%
## Assemble associatedMedia

associatedMedia = []

for occ_id in converted['occurrenceID'].unique():
    
    # Select data associated with that occurrenceID:
    selected = converted[converted['occurrenceID'] == occ_id]
    
    # Retrieve unique image and video files
    image_files = selected['image_url'].drop_duplicates()
    video_files = selected['video_uri'].drop_duplicates()
    
    # Remove any NaN values
    image_files = image_files.dropna()
    video_files = video_files.dropna()
    
    # Join image and video files
    media = pd.concat([image_files, video_files])
    
    # Create a string with all the urls
    url_str = ''
    for url in media: url_str = url_str + url + ' | '
    url_str = url_str[0:-3]
    
    # Add to associatedMedia
    associatedMedia.append(url_str)

# %% [markdown]
# **Note:** The above can take some time depending on how many records must be processed. There's probably a better way to do it, but I'm not going to take the time to update this code right now.

# %%
## Add to df

# First, need to remove rows with duplicate occurrenceIDs
converted = converted.drop_duplicates(subset='occurrenceID', keep="first")

# Add associatedMedia
converted['associatedMedia'] = associatedMedia
converted.head()
# Out:
#                eventDate       eventID samplingProtocol     recordedBy  \
# 1   1989-04-27T17:54:50Z  Ventana_0043              ROV   Chuck Baxter
# 12  1989-05-17T17:13:42Z  Ventana_0050              ROV    Chris Grech
# 14  1989-09-12T22:01:07Z  Ventana_0076              ROV   Chuck Baxter
# 19  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
# 22  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
#
#    datasetID institutionCode                          occurrenceID  \
# 1       VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 12      VARS           MBARI  6198DB37-934F-478A-9820-251627551327
# 14      VARS           MBARI  7A96AB28-8188-425B-BB9F-92E9F35E12FF
# 19      VARS           MBARI  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75
# 22      VARS           MBARI  D09D6A8C-8DDA-4431-81AB-971872DE96A6
#
#                scientificName          occurrenceRemarks identifiedBy  ...  \
# 1         Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
# 12                 Parmaturus                 Parmaturus       amberR  ...
# 14                Galatheidae                Galatheidae      unknown  ...
# 19  Rathbunaster californicus  Rathbunaster californicus      unknown  ...
# 22        Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
#
#     temperatureInCelsius                                          image_url  \
# 1                  6.259  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12                 6.996  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14                 7.930  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19                   NaN  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22                   NaN  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
#                      video_uri  coordinateUncertaintyInMeters  \
# 1   urn:tid:mbari.org:V0043-04                            300
# 12  urn:tid:mbari.org:V0050-02                            300
# 14  urn:tid:mbari.org:V0076-18                            300
# 19  urn:tid:mbari.org:V0049-01                            300
# 22  urn:tid:mbari.org:V0049-01                            300
#
#                              scientificNameID  taxonID  nameAccordingTo  \
# 1   urn:lsid:marinespecies.org:taxname:282166   282166            WoRMS
# 12  urn:lsid:marinespecies.org:taxname:270301   270301            WoRMS
# 14  urn:lsid:marinespecies.org:taxname:106733   106733            WoRMS
# 19  urn:lsid:marinespecies.org:taxname:254844   254844            WoRMS
# 22  urn:lsid:marinespecies.org:taxname:282166   282166            WoRMS
#
#     occurrenceStatus       basisOfRecord  \
# 1            present  MachineObservation
# 12           present  MachineObservation
# 14           present  MachineObservation
# 19           present  MachineObservation
# 22           present  MachineObservation
#
#                                       associatedMedia
# 1   http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
# [5 rows x 28 columns]

# %%
## Save columns for MeasurementOrFact file

mof = converted[['occurrenceID', 'dissolvedOxygenInMLPerL', 'pressureInPsi', 'salinity', 'temperatureInCelsius']]

# %%
## Drop extra columns

converted = converted.drop(['image_url', 'video_uri', 'dissolvedOxygenInMLPerL', 'pressureInPsi', 'salinity', 'temperatureInCelsius'], axis=1)
converted.head()
# Out:
#                eventDate       eventID samplingProtocol     recordedBy  \
# 1   1989-04-27T17:54:50Z  Ventana_0043              ROV   Chuck Baxter
# 12  1989-05-17T17:13:42Z  Ventana_0050              ROV    Chris Grech
# 14  1989-09-12T22:01:07Z  Ventana_0076              ROV   Chuck Baxter
# 19  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
# 22  1989-05-10T16:39:10Z  Ventana_0049              ROV  Chris Harrold
#
#    datasetID institutionCode                          occurrenceID  \
# 1       VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 12      VARS           MBARI  6198DB37-934F-478A-9820-251627551327
# 14      VARS           MBARI  7A96AB28-8188-425B-BB9F-92E9F35E12FF
# 19      VARS           MBARI  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75
# 22      VARS           MBARI  D09D6A8C-8DDA-4431-81AB-971872DE96A6
#
#                scientificName          occurrenceRemarks identifiedBy  ...  \
# 1         Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
# 12                 Parmaturus                 Parmaturus       amberR  ...
# 14                Galatheidae                Galatheidae      unknown  ...
# 19  Rathbunaster californicus  Rathbunaster californicus      unknown  ...
# 22        Parmaturus xaniurus        Parmaturus xaniurus       amberR  ...
#
#     verbatimDepth  decimalLatitude  decimalLongitude  \
# 1           415.0        36.612168       -122.029075
# 12          368.5        36.103195       -121.669329
# 14          329.2        36.699518       -121.997843
# 19          353.1        36.607831       -122.018691
# 22          353.1        36.607831       -122.018691
#
#     coordinateUncertaintyInMeters                           scientificNameID  \
# 1                             300  urn:lsid:marinespecies.org:taxname:282166
# 12                            300  urn:lsid:marinespecies.org:taxname:270301
# 14                            300  urn:lsid:marinespecies.org:taxname:106733
# 19                            300  urn:lsid:marinespecies.org:taxname:254844
# 22                            300  urn:lsid:marinespecies.org:taxname:282166
#
#     taxonID nameAccordingTo  occurrenceStatus       basisOfRecord  \
# 1    282166           WoRMS           present  MachineObservation
# 12   270301           WoRMS           present  MachineObservation
# 14   106733           WoRMS           present  MachineObservation
# 19   254844           WoRMS           present  MachineObservation
# 22   282166           WoRMS           present  MachineObservation
#
#                                       associatedMedia
# 1   http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
# [5 rows x 22 columns]

# %%
## Reorder columns

converted = converted[['eventID', 'eventDate', 'samplingProtocol', 'recordedBy', 'datasetID', 'institutionCode', 'occurrenceID', 'scientificName', 'scientificNameID', 'taxonID', 
                       'nameAccordingTo', 'occurrenceStatus', 'basisOfRecord', 'identifiedBy', 'occurrenceRemarks', 'decimalLatitude', 'decimalLongitude', 'coordinateUncertaintyInMeters',
                       'minimumDepthInMeters', 'maximumDepthInMeters', 'verbatimDepth', 'associatedMedia']]
converted.head()
# Out:
#          eventID             eventDate samplingProtocol     recordedBy  \
# 1   Ventana_0043  1989-04-27T17:54:50Z              ROV   Chuck Baxter
# 12  Ventana_0050  1989-05-17T17:13:42Z              ROV    Chris Grech
# 14  Ventana_0076  1989-09-12T22:01:07Z              ROV   Chuck Baxter
# 19  Ventana_0049  1989-05-10T16:39:10Z              ROV  Chris Harrold
# 22  Ventana_0049  1989-05-10T16:39:10Z              ROV  Chris Harrold
#
#    datasetID institutionCode                          occurrenceID  \
# 1       VARS           MBARI  A916C1F3-4C1A-45A1-B835-A2F0C7517D56
# 12      VARS           MBARI  6198DB37-934F-478A-9820-251627551327
# 14      VARS           MBARI  7A96AB28-8188-425B-BB9F-92E9F35E12FF
# 19      VARS           MBARI  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75
# 22      VARS           MBARI  D09D6A8C-8DDA-4431-81AB-971872DE96A6
#
#                scientificName                           scientificNameID  \
# 1         Parmaturus xaniurus  urn:lsid:marinespecies.org:taxname:282166
# 12                 Parmaturus  urn:lsid:marinespecies.org:taxname:270301
# 14                Galatheidae  urn:lsid:marinespecies.org:taxname:106733
# 19  Rathbunaster californicus  urn:lsid:marinespecies.org:taxname:254844
# 22        Parmaturus xaniurus  urn:lsid:marinespecies.org:taxname:282166
#
#     taxonID  ...       basisOfRecord identifiedBy          occurrenceRemarks  \
# 1    282166  ...  MachineObservation       amberR        Parmaturus xaniurus
# 12   270301  ...  MachineObservation       amberR                 Parmaturus
# 14   106733  ...  MachineObservation      unknown                Galatheidae
# 19   254844  ...  MachineObservation      unknown  Rathbunaster californicus
# 22   282166  ...  MachineObservation       amberR        Parmaturus xaniurus
#
#    decimalLatitude decimalLongitude  coordinateUncertaintyInMeters  \
# 1        36.612168      -122.029075                            300
# 12       36.103195      -121.669329                            300
# 14       36.699518      -121.997843                            300
# 19       36.607831      -122.018691                            300
# 22       36.607831      -122.018691                            300
#
#     minimumDepthInMeters  maximumDepthInMeters  verbatimDepth  \
# 1                  412.8                 417.2          415.0
# 12                 366.3                 370.7          368.5
# 14                 327.0                 331.4          329.2
# 19                 350.9                 355.3          353.1
# 22                 350.9                 355.3          353.1
#
#                                       associatedMedia
# 1   http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 12  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 14  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 19  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
# 22  http://search.mbari.org/ARCHIVE/frameGrabs/Ven...
#
# [5 rows x 22 columns]

# %%
## Save occurrence file

converted.to_csv('VARS_1989_converted_20220104.csv', index=False, na_rep='NaN')

# %% [markdown]
# ### Build MeasurementOrFact file

# %%
## Add columns by occurrenceID

mof.head()
# Out:
#                             occurrenceID  dissolvedOxygenInMLPerL  \
# 1   A916C1F3-4C1A-45A1-B835-A2F0C7517D56                      NaN
# 12  6198DB37-934F-478A-9820-251627551327                      NaN
# 14  7A96AB28-8188-425B-BB9F-92E9F35E12FF                      NaN
# 19  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75                      NaN
# 22  D09D6A8C-8DDA-4431-81AB-971872DE96A6                      NaN
#
#     pressureInPsi   salinity  temperatureInCelsius
# 1            44.0  34.234001                 6.259
# 12          142.0  34.224998                 6.996
# 14          226.0  34.132000                 7.930
# 19           72.0        NaN                   NaN
# 22           72.0        NaN                   NaN

# %%
## Convert to long format

mof_long = pd.melt(mof, id_vars='occurrenceID', var_name='measurementType', value_name='measurementValue')
mof_long.head()
# Out:
#                            occurrenceID          measurementType  \
# 0  A916C1F3-4C1A-45A1-B835-A2F0C7517D56  dissolvedOxygenInMLPerL
# 1  6198DB37-934F-478A-9820-251627551327  dissolvedOxygenInMLPerL
# 2  7A96AB28-8188-425B-BB9F-92E9F35E12FF  dissolvedOxygenInMLPerL
# 3  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75  dissolvedOxygenInMLPerL
# 4  D09D6A8C-8DDA-4431-81AB-971872DE96A6  dissolvedOxygenInMLPerL
#
#    measurementValue
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# There are some rows where salinity=0. That doesn't make sense, and I'm assuming salinity is unavailable for these records. Changing them to NaN.

# %%
## Change salinity = 0 to NaN

mof_long.loc[(mof_long['measurementType'] == 'salinity') & (mof_long['measurementValue'] == 0), 'measurementValue'] = np.nan

# %%
## Round

mof_long['measurementValue'] = round(mof_long['measurementValue'], 2)

# %%
## Change measurementType names

mof_long['measurementType'].replace({
    'dissolvedOxygenInMLPerL':'dissolvedOxygen',
    'pressureInPsi':'pressure',
    'temperatureInCelsius':'temperature'
}, inplace = True)

# %%
## Add measurementUnit

mof_long['measurementUnit'] = 'mL per L seawater'
mof_long.loc[mof_long['measurementType'] == 'pressure', 'measurementUnit'] = 'psi'
mof_long.loc[mof_long['measurementType'] == 'salinity', 'measurementUnit'] = 'psu'
mof_long.loc[mof_long['measurementType'] == 'temperature', 'measurementUnit'] = 'celsius'

mof_long.head()
# Out:
#                            occurrenceID  measurementType  measurementValue  \
# 0  A916C1F3-4C1A-45A1-B835-A2F0C7517D56  dissolvedOxygen               NaN
# 1  6198DB37-934F-478A-9820-251627551327  dissolvedOxygen               NaN
# 2  7A96AB28-8188-425B-BB9F-92E9F35E12FF  dissolvedOxygen               NaN
# 3  6684BDBA-4E42-4DE6-B346-C8F21EAD9E75  dissolvedOxygen               NaN
# 4  D09D6A8C-8DDA-4431-81AB-971872DE96A6  dissolvedOxygen               NaN
#
#      measurementUnit
# 0  mL per L seawater
# 1  mL per L seawater
# 2  mL per L seawater
# 3  mL per L seawater
# 4  mL per L seawater

# %%
## Save

mof_long.to_csv('VARS_1989_MoF_20220104.csv', index=False, na_rep='NaN')

# %% [markdown]
# ### Remaining issues
#
# 1. Metadata
# 2. measurementType --> standard terms?
# 3. Didn't drop NaN values in MoF file
